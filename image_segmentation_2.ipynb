# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
# We have grayscale images, so while loading the images we will keep grayscale=True, if you have RGB images, you should set grayscale as False
train_image = []
for i in tqdm(range(train.shape[0])):
    img = image.load_img('train/'+train['image_name'][i], target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
X = np.array(train_image)
# Out:
#   0%|          | 0/17034 [00:00<?, ?it/s]C:\Users\Nishant Kumar\Anaconda3\lib\site-packages\keras_preprocessing\image\utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 17034/17034 [02:56<00:00, 96.42it/s]

# %%
y=train['label'].values
y = to_categorical(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Nishant Kumar\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Nishant Kumar\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\Nishant Kumar\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 13627 samples, validate on 3407 samples
# Epoch 1/100
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#   image_name
# 0      3.jpg
# 1      5.jpg
# 2      6.jpg
# 3     11.jpg
# 4     14.jpg

# %%
test.shape
# Out:
# (7301, 1)

# %%
test_image = []
for i in tqdm(range(test.shape[0])):
    img = image.load_img('train/'+test['image_name'][i], target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    test_image.append(img)
X = np.array(test_image)
# Out:
# 100%|██████████| 7301/7301 [01:18<00:00, 92.80it/s]

# %%
prediction = model.predict_classes(X)

# %%
prediction
# Out:
# array([1, 0, 4, ..., 2, 1, 0], dtype=int64)

# %%
solution=pd.read_csv("sample_submission.csv")

# %%
solution.head()
# Out:
#   image_name  label
# 0      3.jpg      5
# 1      5.jpg      0
# 2      6.jpg      4
# 3     11.jpg      2
# 4     14.jpg      5

# %%
solution["label"]=prediction

# %%
solution.head()
# Out:
#   image_name  label
# 0      3.jpg      1
# 1      5.jpg      0
# 2      6.jpg      4
# 3     11.jpg      2
# 4     14.jpg      5

# %%
solution.to_csv("sample_submission.csv",index=False)
